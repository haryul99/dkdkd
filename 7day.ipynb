# %%
import requests
from bs4 import BeautifulSoup


response = requests.get("http://www.summet.com/dmsi/html/codesamples/addresses.html")

html_doc = response.text

soup = BeautifulSoup(html_doc, "html.parser")
print(soup.title)  # str이 아닌 html문서로 찾는 방법
# print(soup.title.name) # 태그의 이름
# print(soup.title.string)#태그의 값
# print(soup.title.text)  #위에랑 동일한 태그의 값

# # print(soup.ul.li)
# print(soup.find('h1'))
# print(soup.find_all('li')) #여러개 찾아주는 것, return type list



# print(response.content ) 네이버 보는 것,
# print(response.text )
# response = requests.get("https://httpbin.org/get")  이 사이트 get한 것
# response = requests.get("https://httpbin.org/put")
# response = requests.get("https://httpbin.org/ip")
# print(response, type(response))
# print(response.status_code)
# print(response.encoding)
# print(response.content)
# print(response.text)
# Out:
# <title>Sample Addresses!</title>

# %%
li_list = soup.find_all('li')

# print(li_list, type(li_list))


# for i in li_list :
    # print(type(i))    
    # print(i.get_text())

# %%
response = requests.get("https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=bts")
html_doc = response.text

soup = BeautifulSoup(html_doc, "html.parser")
# soup.find_all('a',{'href':'#newsstand'})  #, 하고 속성값을 넣을 수 있음
# soup.find_all('button', {'type' :'button'})
# soup.select('a') #자식을 찾기 쉬움 >을 사용하면 됨
soup.select('#header > div.special_bg > div > div.service_area > a.link_jrnaver > span ') #카피(우측클릭) 셀렉터를 하면 됨
# soup.select('#main_pack > section.sc_new.sp_nnews._prs_nws_all > div > div.group_news > ul')
# soup.find_all('a',{'class' : 'news_tit'})
tag = soup.select_one('#main_pack > section.sc_new.sp_nnews._prs_nws_all > div > div.group_news > ul')

news_list = tag.select('li > div > div > a') # 찾아가기 위함

for n in news_list :
    print(n.get_text()) #str
    print(n.get_attribute_list('href'))
    # print(n.get_attribute_list('title')) list로 담음
# Out:
# 한 벌에 12만원…BTS도 놀란 ‘BTS 잠옷’ 가격
# ['https://www.chosun.com/economy/industry-company/2022/01/04/5RBS7KTE6JFWVNJX4BCKC4VKJ4/?utm_source=naver&utm_medium=referral&utm_campaign=naver-news']
# BTS 뷔가 부른 OST, 한국 첫 빌보드 ‘핫 100‘ 진입
# ['https://www.seoul.co.kr/news/newsView.php?id=20220105500019&wlog_tag3=naver']
# 네이버웹툰, BTS 슈퍼캐스팅 옥외광고 코엑스 케이팝 스퀘어에 공개
# ['http://www.fnnews.com/news/202201040847465379']
# BTS 후보 오른 그래미 시상식, 오미크론 여파 연기 가능성
# ['http://yna.kr/AKR20220105005100075?did=1195m']

# %%
response = requests.get("https://www.daangn.com/search/%EB%85%B8%ED%8A%B8%EB%B6%81")
html_doc = response.text
soup = BeautifulSoup(html_doc, "html.parser")  #BeautifulSoup이란 str을 html 문서로 변경해주는 것


tag = soup.select_one('#result > div:nth-child(1)')
# print(tag)
# new_list = tag.select('div > p > article > a > div > img > div > div > span')
news_list = tag.select('span.article-title ')
for n in news_list :
    print(n.get_text())
    
soup.find_all('span',{'class' : 'article-title'})
# Out:
# 삼성 노트북, 미니노트북, 11인치 노트북, 아티브북m(nt110s1j-k11s) 12만원
# 고사양 노트북, 게이밍노트북, 노트북, 영상편집 노트북
# 노트북 HP 파빌리온 14 N291TX  i5 노트북(+냉각팬달린 노트북받침)
# 캉골 크로스백 노트북백 노트북크로스백 노트북가방
# 고급형 144hz 게이밍 노트북 MSI I7 8750H  GTX1060 노트북 팝니다.
# 뉴발란스노트북가방, 뉴발란스노트북백팩
# [<span class="article-title">삼성 노트북, 미니노트북, 11인치 노트북, 아티브북m(nt110s1j-k11s) 12만원</span>,
#  <span class="article-title">고사양 노트북, 게이밍노트북, 노트북, 영상편집 노트북</span>,
#  <span class="article-title">노트북 HP 파빌리온 14 N291TX  i5 노트북(+냉각팬달린 노트북받침)</span>,
#  <span class="article-title">캉골 크로스백 노트북백 노트북크로스백 노트북가방</span>,
#  <span class="article-title">고급형 144hz 게이밍 노트북 MSI I7 8750H  GTX1060 노트북 팝니다.</span>,
#  <span class="article-title">뉴발란스노트북가방, 뉴발란스노트북백팩</span>]

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\bit\anaconda3\lib\site-packages (4.1.0)
# Requirement already satisfied: trio~=0.17 in c:\users\bit\anaconda3\lib\site-packages (from selenium) (0.19.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\bit\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[secure]~=1.26 in c:\users\bit\anaconda3\lib\site-packages (from selenium) (1.26.7)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\bit\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\bit\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: sniffio in c:\users\bit\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\bit\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Requirement already satisfied: idna in c:\users\bit\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: async-generator>=1.9 in c:\users\bit\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: outcome in c:\users\bit\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: pycparser in c:\users\bit\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\users\bit\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.0.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\bit\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\bit\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in c:\users\bit\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: six>=1.5.2 in c:\users\bit\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\bit\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.12.0)

# %%
from selenium import webdriver
driver = webdriver.Chrome('driver/chromedriver') #하위 객체에 있어야 함
driver.get("https://nid.naver.com/nidlogin.login?mode=form&url=https%3A%2F%2Fwww.naver.com")

# driver.save_screenshot('001.png') #화면 캡처
elem_login = driver.find_element_by_id('id')
elem_login.clear()
elem_login.send_keys("haryulpark")

elem_login = driver.find_element_by_id("pw")
elem_login.clear() #기존 값을 지우는 뜻
elem_login.send_keys("@a37983705")
xpath = """//*[@id="log.login"]"""
driver.find_element_by_xpath(xpath).click()
xpath = """/html/body/div/div/div[1]/div[1]/a[1]"""
driver.find_element_by_xpath(xpath).click()
# Out:
# C:\Users\BIT\AppData\Local\Temp/ipykernel_8512/1579777362.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('driver/chromedriver') #하위 객체에 있어야 함
# C:\Users\BIT\AppData\Local\Temp/ipykernel_8512/1579777362.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem_login = driver.find_element_by_id('id')
# C:\Users\BIT\AppData\Local\Temp/ipykernel_8512/1579777362.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem_login = driver.find_element_by_id("pw")
# C:\Users\BIT\AppData\Local\Temp/ipykernel_8512/1579777362.py:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(xpath).click()
# C:\Users\BIT\AppData\Local\Temp/ipykernel_8512/1579777362.py:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(xpath).click()

# %%
import requests
from selenium import webdriver
import re
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome('driver/chromedriver') #하위 객체에 있어야 함
driver.get("https://comic.naver.com/index")

clickAcomic = driver.find_element_by_xpath('//*[@id="genreRecommand"]/li[3]/div[1]/a/span')

clickAcomic.click() #스파이더맨 선택

contantOpen = driver.find_element_by_xpath('//*[@id="content"]/div[2]/div/a[1]')

contantOpen.click() # 두번째 장 선택

contantselect = driver.find_element_by_xpath('//*[@id="content"]/table/tbody/tr[2]/td[1]/a/span')

contantselect.click() #임의의 comic select

driver.execute_script('window.scrollTo(0, document.body.scrollHeight);') #최하단으로 내려가는 코드

r = driver.current_url #현재 url얻기
response = requests.get(r)
html_doc = response.text
soup = BeautifulSoup(html_doc, "html.parser")

tag = soup.select_one('#cbox_module_wai_u_cbox_content_wrap_tabpanel > ul > li.u_cbox_comment.cbox_module__comment_425681884._user_id_no_4Lp3h > div.u_cbox_comment_box > div > div.u_cbox_text_wrap')

# o = response.text
# p = re.compile(".*[가-힣]+.*")
# print(p.findall(o))
               
# with open("hi.txt", "w", encoding="utf-8") as comment :
#     for n in phone_num :
#         phone.write('%s \n' %n)
        
        
# search_box.send_keys('11')
# driver.implicitly_wait(3)

# search_box.send_keys(Keys.RETURN)
# Out:
# C:\Users\BIT\AppData\Local\Temp/ipykernel_8512/2918978755.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('driver/chromedriver') #하위 객체에 있어야 함
# C:\Users\BIT\AppData\Local\Temp/ipykernel_8512/2918978755.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   clickAcomic = driver.find_element_by_xpath('//*[@id="genreRecommand"]/li[3]/div[1]/a/span')
# C:\Users\BIT\AppData\Local\Temp/ipykernel_8512/2918978755.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   contantOpen = driver.find_element_by_xpath('//*[@id="content"]/div[2]/div/a[1]')
# C:\Users\BIT\AppData\Local\Temp/ipykernel_8512/2918978755.py:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   contantselect = driver.find_element_by_xpath('//*[@id="content"]/table/tbody/tr[2]/td[1]/a/span')
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#
#
#
#
#
#
#
# 	<meta http-equiv="Content-type" content="text/html; charset=UTF-8">
# 	<title>언덕 위의 제임스 :: 네이버 만화</title>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <meta property="og:title" content="언덕 위의 제임스 - 301화 조선 침술사 (1)" >
#
#         <meta property="og:image" content="https://shared-comic.pstatic.net/thumb/webtoon/671421/303/thumbnail_600x315_90813275-1ac3-49f7-987c-c4653ea597e5.jpg" >
#         <meta property="og:description" content="301화 조선 침술사 (1)">
#
#
#
#
#
#
#
#
#
# <meta property="og:url" content="https://comic.naver.com/webtoon/detail?titleId=671421&amp;no=303&amp;weekday=wed" >
# <meta property="og:type" content="article" >
# <meta property="og:article:author" content="네이버 웹툰" >
# <meta property="og:article:author:url" content="https://comic.naver.com" >
#
# 	<link rel="shortcut icon" href="https://ssl.pstatic.net/static/comic/favicon/webtoon_favicon_32x32.ico" type="image/x-icon">
#
# 	<script type="text/javascript">
# 		document.domain = "naver.com";
# 	</script>
# 	<meta http-equiv="Content-Script-Type" content="text/javascript">
# <meta http-equiv="Content-Style-Type" content="text/css">
#
# <meta http-equiv="X-UA-Compatible" content="IE=edge, chrome=1">
#
#
#
#
#
# 		<link rel="stylesheet" style="text/css" href="/css/comic/comic_20211220192220.css">
# 		<link rel="stylesheet" style="text/css" href="/css/comic/view_20211220192220.css">
#
#
# <script type="text/javascript" src="/aggregate/javascript/release/comic_detailscroll_20211220192220.js"></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <style type="text/css">
# @media screen and (max-width:720px) {
#  .sc_plugin.ly_link{left:initial;right:0;}
# }
# </style>
#
# 		<script type="text/javascript" src="/aggregate/javascript/release/comic_gnb_20211220192220.js"></script>
#
# </head>
#
#
#
#
#
#
#
#
#
#
# <body onload="">
#
#
#
#
#
#
#
#
# 	<div id="wrap"  class="end_page"    >
#
#
#
#
# 				<a href="#content" class="blind">본문 바로가기</a>
#
#
#
# 		<div id="header_wrap">
# 			<div id="header">
#
#
#
# <div id="gnb">
#     <script type="text/javascript">
#         var gnb_option = {
#             gnb_service : "comic",
#             gnb_logout :  encodeURIComponent(window.location.href),
#             gnb_login :   encodeURIComponent(window.location.href),
#             gnb_template : "gnb_utf8",
#             gnb_brightness : 1,
#             gnb_item_hide_option: 0
#         };
#     </script>
#     <script type="text/javascript" charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8?20211220192220"></script>
# </div>
# <div id="snb_wrap">
#     <h1>
#         <a onclick="nclk_v2(event,'STA.naverlogo')" href="https://www.naver.com" title="NAVER" class="Ntxt_naver">NAVER</a>
#         <a onclick="nclk_v2(event,'STA.comic')" href="/index" title="만화" class="Ntxt_comic">만화</a>
#         <em class="bar">|</em>
#         <a onclick="nclk_v2(event,'STA.novel')" href="https://novel.naver.com" title="웹소설" class="Ntxt_novel">웹소설</a>
#     </h1>
#
#
#     <form id="searchForm" name="search" method="get" action="/search">
#         <fieldset>
#             <legend>검색</legend>
#             <div class="snb_search_box">
#                 <div class="snb_search_box_sub">
#
#
#
#
#
#
#
#
#
#                     <!-- [D] 클릭시 label.ph 텍스트 삭제해주세요. -->
#                     <label class="ph" for="gnb.keyword">제목/작가로 검색할 수 있습니다.</label>
#                     <input type="text" id="gnb.keyword" name="keyword" value="" title="검색어 입력" maxlength="18" class="snb_search_text">
#                     <button type="button" class="btn_search" id="search_bar_button" onclick="nclk_v2(event,'STA.search')" title="검색" alt="검색"><span class="Nico_search">검색</span></button>
#                 </div>
#             </div>
#         </fieldset>
#     </form>
#
# </div>
#
# 				<div id="author_layer" style="text-align:left; display:none;">
# 					<ul id="author_layer_inner">&nbsp;</ul>
# 				</div>
#
#
#
#
#
# 					<div class="notice_info">
# 						<span class="blind">공지사항</span>
# 						<div class="rolling">
#
#
# 							<div class="notice_rolling">
# 								<li>
# 									<a onclick="nclk_v2(event,'STA.txt')" href="https://comic.naver.com/webtoon/list.nhn?titleId=785855" title="짝사랑했던 그 애가 나를 좋아했었다고? &lt;짝사랑 마들렌&gt;">
# 										<span class="Nico_notice"></span>
# 										짝사랑했던 그 애가 나를 좋아했었다고? &lt;짝사랑 마들렌&gt;
# 									</a>
# 								</li>
# 							</div>
# 						</div>
# 					</div>
#
# 			</div>
# 			<div id="menu">
# 				<ul class="menu">
# 					<!-- [D] 선택된 li에 current 클래스 추가 -->
# 					<li ><a onclick="nclk_v2(event,'LNB.home');" href="/index"><span class="Ntxt_home">웹툰 홈</span></a></li>
# 					<li class="current"><a onclick="nclk_v2(event,'LNB.toon');" href="/webtoon/weekday"><span class="Ntxt_webtoon">웹툰</span></a></li>
# 					<li ><a onclick="nclk_v2(event,'LNB.best');" href="/genre/bestChallenge"><span class="Ntxt_best_challenge">베스트 도전</span></a></li>
# 					<li ><a onclick="nclk_v2(event,'LNB.chal');" href="/genre/challenge"><span class="Ntxt_challenge_comic">도전만화</span></a></li>
# 					<li ><a onclick="nclk_v2(event,'LNB.my');" href="/mypage/favorite"><span class="Ntxt_mypage">마이페이지</span></a><span class="bar"></span></li>
# 					<li><a onclick="nclk_v2(event,'LNB.char');" href="https://series.naver.com/comic/recommendList.series" target="_blank"><span class="Ntxt_short_story">단행본 만화</span></a></li>
# 					<li class="genre_novel"><a onclick="nclk_v2(event,'LNB.novel');" href="https://series.naver.com/novel/recommendList.series" target="_blank"><span class="Ntxt_genre_novel">장르소설</span></a></li>
# 				</ul>
# 				<h2 class="blind">웹툰</h2>
# 			</div>
# 			<!-- //상단 메뉴 /webtoon/detail-->
#
#
#
#
#
#
#
#
#
#
# <div id="submenu">
# 	<!--서브메뉴-->
# 	<ul class="submenu">
# 		<!-- [D] 선택된 li에 on 클래스 추가 -->
# 		<li class="on"><a onclick="nclk_v2(event,'tab.weekday')" href="/webtoon/weekday"><span class="Ntxt_menu_date">요일별</span></a></li>
# 		<li ><a onclick="nclk_v2(event,'tab.genre')" href="/webtoon/genre"><span class="Ntxt_menu_genre">장르별</span></a></li>
# 		<li ><a onclick="nclk_v2(event,'tab.creation')" href="/webtoon/creation"><span class="Ntxt_menu_art">작품별</span></a></li>
# 		<li ><a onclick="nclk_v2(event,'tab.artist')" href="/webtoon/artist"><span class="Ntxt_menu_author">작가별</span></a></li>
# 		<li ><a onclick="nclk_v2(event,'tab.period')" href="/webtoon/period"><span class="Ntxt_menu_year">연도별</span></a></li>
# 		<li ><a onclick="nclk_v2(event,'tab.theme')" href="/webtoon/theme"><span class="Ntxt_menu_theme">테마웹툰</span></a></li>
# 		<li ><a onclick="nclk_v2(event,'tab.finish')" href="/webtoon/finish"><span class="Ntxt_menu_end">완결웹툰</span></a></li>
# 	</ul>
# 	<!--//서브메뉴-->
# </div>
#
#
# 		</div>
# 		<!-- 상단 영역(메인에만 나감.) -->
#
# 		<!-- //상단 영역 -->
#
# 		<div id="container" class="">
#
#
#
#
#
# 			<div id="content" class="webtoon">
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		<ul class="category_tab">
# 			<li class=""><a onclick="nclk_v2(event,'dna.all')" href="/webtoon/weekday">요일전체</a></li>
# 			<li class=""><a onclick="nclk_v2(event,'dna.monday')" href="/webtoon/weekdayList?week=mon">월요웹툰</a></li>
# 			<li class=""><a onclick="nclk_v2(event,'dna.tuesday')" href="/webtoon/weekdayList?week=tue">화요웹툰</a></li>
# 			<li class="on"><a onclick="nclk_v2(event,'dna.wednesday')" href="/webtoon/weekdayList?week=wed">수요웹툰</a></li>
# 			<li class=""><a onclick="nclk_v2(event,'dna.thursday')" href="/webtoon/weekdayList?week=thu">목요웹툰</a></li>
# 			<li class=""><a onclick="nclk_v2(event,'dna.friday')" href="/webtoon/weekdayList?week=fri">금요웹툰</a></li>
# 			<li class=""><a onclick="nclk_v2(event,'dna.saturday')" href="/webtoon/weekdayList?week=sat">토요웹툰</a></li>
# 			<li class=""><a onclick="nclk_v2(event,'dna.sunday')" href="/webtoon/weekdayList?week=sun">일요웹툰</a></li>
# 			<li class=""><a onclick="nclk_v2(event,'dna.daily')" href="/webtoon/weekdayList?week=dailyplus">매일+웹툰</a></li>
# 		</ul>
#
#
#
#
#
#
#
# 				<!-- body -->
# 				<script type="text/javascript">
#     jQuery.noConflict()
#     function loadImageEvent(element){
#         if ( element ) {
#             if( element.width && element.width > 900 ) {
#                 element.width = 900;
#             }
#         }
#     }
#     window.__state__ = {
#         staticDomain: ''
#     }
# </script>
#             <!-- //tab -->
# 			<div class="section_cont wide" id="sectionContWide">
#
#             	<div class="comicinfo">
#
#
# 						<div class="thumb">
# 							<a onclick="javascript:nclk_v2(event,'inf.img');" href="/webtoon/list?titleId=671421&no=303&weekday=wed">
# 								<img src="https://shared-comic.pstatic.net/thumb/webtoon/671421/thumbnail/thumbnail_IMAG04_5bba5e68-c7d5-4eb8-b6d3-ba342c17b131.jpg" title="언덕 위의 제임스" alt="언덕 위의 제임스" width="218" height="120" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'">
# 								<span class="mask"></span>
#
# 							</a>
# 						</div>
#
#
#
#                 	 <div class="detail">
#
#                 	 	<h2>언덕 위의 제임스<span class="wrt_nm">                	 쿠당탕</span>
#
#                 	 	</h2>
#
# 							<p class="txt">제임스들이 펼치는 코믹 막장 에피소드!<br>지금 전세계의 제임스들이 몰려온다</p>
#
#
#
#
# 							 <p class="detail_info"><span class="genre">에피소드, 개그</span><span class="age">전체연령가</span></p>
#
#                         <ul class="btn_group">
#
#                         	<li>
# 								<a onclick="return actionRunner.addFavoriteWebtoon('671421', 'inf', event);" title="관심웹툰" class="book_maker ">
# 									<span >관심웹툰</span>
# 								</a>
# 							</li>
#
#                         <li><a onclick="nclk_v2(event,'inf.first');return checkServiceCode('subTitle','S00','1');" href="#" title="첫회보기" class="first"><span >첫회보기</span></a></li>
#                         <li><a onclick="nclk_v2(event,'inf.list')" href="/webtoon/list?titleId=671421&weekday=wed" title="목록보기" class="lst"><span >목록보기</span></a></li>
# 						<li><a href="#" onclick="nclk_v2(event,'inf.artist');return actionRunner.artistForArtistTitle(this);" title="작가의 다른 작품" id="other_content" class="other"><span >작가의 다른 작품</span></a></li>
#
#                         </ul>
#                 	</div>
#                 </div>
#
#                 <div class="tit_area">
#                 	<div class="view">
#                     	<h3>301화 조선 침술사 (1)</h3>
#                         <div class="btn_area">
#                         	<!-- 유료화구간 -->
#
#
# 								<span class="pre">
# 									<a onclick="nclk_v2(event,'bdt.prev');return checkServiceCode('subTitle','S00','302');" href="#">이전화</a>
# 								</span>
#
#
# 								<span class="bar">|</span>
# 								<span class="next">
# 									<a onclick="nclk_v2(event,'bdt.next');return checkServiceCode('subTitle','S00','304');" href="#">다음화</a>
# 								</span>
#
#                         </div>
#                     </div>
#                     <div class="vote_lst">
#                     	<dl class="lt">
#                         <dt><img src="https://ssl.pstatic.net/static/comic/images/migration/detail/txt_point_all.gif" width="39" height="11" alt="회별별점" ></dt>
#                         <dd class="total">
#                             <div class="rating_type4" id="topTotalStarPoint">
#                                 <span class="star"><em style="width:99%">평점</em></span>
#                                 <span id="topPointTotalNumber"><strong>9.96</strong></span>
#                                 <span class="pointTotalPerson">(참여 <em>2009</em>)</span>
#                             </div>
#                         </dd>
#
#                         <dt id="topStarLabel"><img src="https://ssl.pstatic.net/static/comic/images/migration/detail/txt_point_click.gif" width="38" height="11" class="starscore_guide_txt" alt="별점주기"></dt>
#                         <dd id="topStarSelectbox">
#                             <div class="pointSelect fl" >
#                                 <a onclick="nclk_v2(event,'bdt.star','','11')" href="#" class="default" id="starScoreMenu_1"><span class="star_type4"><span id="topTargetMask" class="mask" style="width:100%"><img src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60" height="12" alt="점수선택" class="starscore_star_pic" ></span></span></a>
#                                 <ul style="display:none" id="pointSelectOption">
#                                 <li><a onclick="nclk_v2(event,'bdt.star','','10')" href="#" id="topStar10Select" title="10점"><span class="star_type4"><span class="mask" style="width:100%"><img src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60" height="12" alt="10점">10점</span></span></a></li>
#                                 <li><a onclick="nclk_v2(event,'bdt.star','','9')" href="#" id="topStar9Select" title="9점"><span class="star_type4"><span class="mask" style="width:90%"><img src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60" height="12" alt="9점">9점</span></span></a></li>
#                                 <li><a onclick="nclk_v2(event,'bdt.star','','8')" href="#" id="topStar8Select" title="8점"><span class="star_type4"><span class="mask" style="width:80%"><img src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60" height="12" alt="8점">8점</span></span></a></li>
#                                 <li><a onclick="nclk_v2(event,'bdt.star','','7')" href="#" id="topStar7Select" title="7점"><span class="star_type4"><span class="mask" style="width:70%"><img src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60" height="12" alt="7점">7점</span></span></a></li>
#                                 <li><a onclick="nclk_v2(event,'bdt.star','','6')" href="#" id="topStar6Select" title="6점"><span class="star_type4"><span class="mask" style="width:60%"><img src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60" height="12" alt="6점">6점</span></span></a></li>
#                                 <li><a onclick="nclk_v2(event,'bdt.star','','5')" href="#" id="topStar5Select" title="5점"><span class="star_type4"><span class="mask" style="width:50%"><img src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60" height="12" alt="5점">5점</span></span></a></li>
#                                 <li><a onclick="nclk_v2(event,'bdt.star','','4')" href="#" id="topStar4Select" title="4점"><span class="star_type4"><span class="mask" style="width:40%"><img src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60" height="12" alt="4점">4점</span></span></a></li>
#                                 <li><a onclick="nclk_v2(event,'bdt.star','','3')" href="#" id="topStar3Select" title="3점"><span class="star_type4"><span class="mask" style="width:30%"><img src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60" height="12" alt="3점">3점</span></span></a></li>
#                                 <li><a onclick="nclk_v2(event,'bdt.star','','2')" href="#" id="topStar2Select" title="2점"><span class="star_type4"><span class="mask" style="width:20%"><img src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60" height="12" alt="2점">2점</span></span></a></li>
#                                 <li><a onclick="nclk_v2(event,'bdt.star','','1')" href="#" id="topStar1Select" title="1점"><span class="star_type4"><span class="mask" style="width:10%"><img src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60" height="12" alt="1점">1점</span></span></a></li>
#                                 </ul>
#                             </div>
#                             <a href="#" class="btn_bx fl" id="topStarScoreSubmitButton" onclick="nclk_v2(event,'bdt.starok');"  ><span>확인</span></a>
#                     	</dd>
#                     	<dd id="topStarText" class="txt" style="display:none;"><span>참여하셨습니다.</span></dd>
#
#
#
#
#
#
#
#
#
#
#
#
#                         </dl>
#                         <dl class="rt">
#                         <dt>등록일</dt>
#                     	<dd class="date">2021.10.26</dd>
#
#                         <dt class="blind">주소복사</dt>
#                     	<dd class="add">
#                         	<a onclick="nclk_v2(event,'bdt.url')" href="#" id="copyUrlActionMenu" class="btn_bx"><span>주소복사</span></a>
#                             <!-- [D] layer 주소복사 -->
# 	                       	<div id="layerAddressBox" style="display:none;top:22px;right:11px;z-index:500;">
# 								<div class="layerAddressBg">
# 									<div class="layerAddress">
# 										<address id="thisUrl">https://comic.naver.com/webtoon/detail?titleId=671421&no=303</address>
# 										클립보드에 주소가 복사되었습니다.<br>
# 										<span class="key">[ctrl+v]</span>를 이용하여 주소를 붙여넣기 하실 수 있습니다.
# 										<a href="#"><img src="https://ssl.pstatic.net/static/comic/images/migration/common/btn_close_layer.gif" title="닫기" alt="닫기" width="15" height="14"></a>
# 									</div>
# 								</div>
# 							</div>
# 							<!-- //layer 주소복사 -->
#                         </dd>
#                         <dt class="blind">리모컨 컨트롤</dt>
#                         	<dd class="remote_area on" id="ddRemoteConOnOff"><a id="btnRemoteConOnOff" href="#" class="btn_bx btn_remote">리모컨 <em>ON</em></a>
# <!-- 리모컨 -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		<div id="comicRemocon" class="_remoteControl remote" style="display: block; position:fixed;top:481.5px;left:1813px;z-index:1000;cursor:move">
#
# 			<div class="h_area">
#                   <strong>리모콘</strong>
#             </div>
#  			<div class="remote_cont">
#                         <a href="#" class="tit">언덕 위의 제임스</a>
#                         <div class="btn_area">
#
#
# 								<a onclick="nclk_v2(event,'con.first');return checkServiceCode('remoteCtr','S00','1');" href="#" title="맨 처음" class="btn_prev_end">처음</a>
#
#
#
#
#
# 								<a onclick="nclk_v2(event,'con.prev');return checkServiceCode('remoteCtr','S00','302');" href="#" title="이전" class="btn_prev">이전</a>
#
#
#
#
#
# 								<a onclick="nclk_v2(event,'con.next');return checkServiceCode('remoteCtr','S00','304');" href="#" title="다음" class="btn_next">다음</a>
#
#
#
#
#
# 								<a onclick="nclk_v2(event,'con.last');return checkServiceCode('remoteCtr','S00','313');" href="#" title="맨 마지막" class="btn_next_end">맨 마지막</a>
#
#
#
#                         </div>
#                         <div class="pg_area">
#                                 <input type="text" onclick="return clickInputFocus(event, this)" onkeyup="moveArticleByEnterKey(event, 'webtoon',671421,'comicSequence')" id="comicSequence" value="302" title="이동 페이지입력" alt="이동 페이지입력" style="width:31px">
#                                 <span>/</span>
#                                 <span class="total">312</span>
#                                 <a  onclick="moveArticleByTitleIdSeq('webtoon',671421,'comicSequence')" href="#" id="goButton" class="btn_move" ><span class="blind">이동</span></a>
#                         </div>
#                         <div class="pg_area2">
#                                 <a href="#@" onclick="javascript:nclk_v2(event,'con.up'); goUp(); return false;" class="btn_up">맨위로</a>
#                                 <a href="#@" onclick="javascript:nclk_v2(event,'con.down'); goDown(); return false;"  class="btn_down">아래로</a>
#                                 <a onclick="nclk_v2(event,'con.list')" href="/webtoon/list?titleId=671421" class="btn_lst">목록</a>
#                         </div>
#                 </div>
#                 <a href="#" id="butt" onclick="nclk_v2(event,'con.close'); return false;" class="btn_clse" title="닫기">닫기</a>
#
# <!-- //리모컨 -->
#                         </dl>
#                     </div>
#                 </div>
# 				<div class="view_area "  id="comic_view_area">
#                 	<!-- 뷰어  -->
#
#
#
#
#
#                     <div class="wt_viewer" style="background:#FFFFFF">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_1.jpg" title="" alt="comic content" id="content_image_0" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_2.jpg" title="" alt="comic content" id="content_image_1" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_3.jpg" title="" alt="comic content" id="content_image_2" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_4.jpg" title="" alt="comic content" id="content_image_3" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_5.jpg" title="" alt="comic content" id="content_image_4" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_6.jpg" title="" alt="comic content" id="content_image_5" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_7.jpg" title="" alt="comic content" id="content_image_6" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_8.jpg" title="" alt="comic content" id="content_image_7" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_9.jpg" title="" alt="comic content" id="content_image_8" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_10.jpg" title="" alt="comic content" id="content_image_9" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_11.jpg" title="" alt="comic content" id="content_image_10" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_12.jpg" title="" alt="comic content" id="content_image_11" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_13.jpg" title="" alt="comic content" id="content_image_12" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_14.jpg" title="" alt="comic content" id="content_image_13" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_15.jpg" title="" alt="comic content" id="content_image_14" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_16.jpg" title="" alt="comic content" id="content_image_15" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_17.jpg" title="" alt="comic content" id="content_image_16" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_18.jpg" title="" alt="comic content" id="content_image_17" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_19.jpg" title="" alt="comic content" id="content_image_18" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_20.jpg" title="" alt="comic content" id="content_image_19" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_21.jpg" title="" alt="comic content" id="content_image_20" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_22.jpg" title="" alt="comic content" id="content_image_21" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_23.jpg" title="" alt="comic content" id="content_image_22" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_24.jpg" title="" alt="comic content" id="content_image_23" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_25.jpg" title="" alt="comic content" id="content_image_24" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_26.jpg" title="" alt="comic content" id="content_image_25" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_27.jpg" title="" alt="comic content" id="content_image_26" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_28.jpg" title="" alt="comic content" id="content_image_27" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_29.jpg" title="" alt="comic content" id="content_image_28" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_30.jpg" title="" alt="comic content" id="content_image_29" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_31.jpg" title="" alt="comic content" id="content_image_30" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_32.jpg" title="" alt="comic content" id="content_image_31" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_33.jpg" title="" alt="comic content" id="content_image_32" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_34.jpg" title="" alt="comic content" id="content_image_33" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_35.jpg" title="" alt="comic content" id="content_image_34" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_36.jpg" title="" alt="comic content" id="content_image_35" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_37.jpg" title="" alt="comic content" id="content_image_36" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_38.jpg" title="" alt="comic content" id="content_image_37" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_39.jpg" title="" alt="comic content" id="content_image_38" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_40.jpg" title="" alt="comic content" id="content_image_39" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_41.jpg" title="" alt="comic content" id="content_image_40" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_42.jpg" title="" alt="comic content" id="content_image_41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_43.jpg" title="" alt="comic content" id="content_image_42" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_44.jpg" title="" alt="comic content" id="content_image_43" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_45.jpg" title="" alt="comic content" id="content_image_44" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_46.jpg" title="" alt="comic content" id="content_image_45" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_47.jpg" title="" alt="comic content" id="content_image_46" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_48.jpg" title="" alt="comic content" id="content_image_47" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_49.jpg" title="" alt="comic content" id="content_image_48" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_50.jpg" title="" alt="comic content" id="content_image_49" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_51.jpg" title="" alt="comic content" id="content_image_50" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_52.jpg" title="" alt="comic content" id="content_image_51" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_53.jpg" title="" alt="comic content" id="content_image_52" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_54.jpg" title="" alt="comic content" id="content_image_53" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_55.jpg" title="" alt="comic content" id="content_image_54" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_56.jpg" title="" alt="comic content" id="content_image_55" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_57.jpg" title="" alt="comic content" id="content_image_56" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_58.jpg" title="" alt="comic content" id="content_image_57" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_59.jpg" title="" alt="comic content" id="content_image_58" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<img src="https://image-comic.pstatic.net/webtoon/671421/303/20211005164813_a89490d9161a4cc6e180ccc227956cff_IMAG01_60.jpg" title="" alt="comic content" id="content_image_59" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" oncontextmenu="return false" ondragstart="return false" onselectstart="return false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# 		} else {
# 			alert('복사 기능을 지원하지 않는 브라우저입니다.');
# 			return false;
# 		}
# 	}
#     var actionRunner;
#
#     WebtoonArtistActionRunner = $Class ({
#         $init : function(titleId) {
#             this._titleId = titleId;
#         },
#
#         addFavoriteWebtoon : function (titleId, nclickArea, event) {
# 	    	var width = (screen.width / 2) - 800;
# 			var height = (screen.height / 2) - 510;
# 			var favoriteUrl = null;
# 			var addUrl = "https://" + location.hostname + "/mypage/favoriteTitleAdd?titleId="+titleId;
# 			var removeUrl = "https://" + location.hostname + "/mypage/favoriteTitleRemove?titleId="+titleId;
# 			if($Element(jindo.$$.getSingle('.book_maker')).hasClass('on')) {
# 				favoriteUrl = removeUrl;
#                 nclk_v2(event, nclickArea + '.zzimdel');
# 			} else {
# 				favoriteUrl = addUrl;
# 				console.log(event);
#                 nclk_v2(event, nclickArea + '.zzim');
# 			}
#
# 			if(isLogin) {
# 			    var favoritePopup = window.open('', 'addFavorite', 'directories=no,toolbar=no,scrollbars=yes,width=370,height=180,top=' + height + ',left=' + width);
# 			    favoritePopup.location.href = favoriteUrl;
# 			} else {
# 			    location.href = "/common/login?url=" + encodeURIComponent(location.href);
# 			}
# 	    },
#
# 		artistForArtistTitle : function(element) {
# 			$Element("author_layer_inner").html("");
# 			$Element("author_layer").css("border", "");
# 			$Element("author_layer_inner").css("border", "1px solid #b6b6b6");
# 			if(artistData.length == 0) {
# 				var liElement = new $Element("<li>");
# 				var spanElement = new $Element("<span>");
# 				spanElement.html("작가의 다른 작품이 없습니다.");
# 				liElement.append(spanElement);
# 				$Element("author_layer_inner").append(liElement);
# 				artistLayer.show(element);
# 			} else if(artistData.length == 1) {
# 				location.href = "/artistTitle?artistId=" + artistData[0].artistId;
# 			} else {
# 				for (var i = 0; i < artistData.length; i++) {
# 					var liElement = new $Element("<li>");
# 					var aElement = new $Element("<a>");
# 					aElement.attr("href", "/artistTitle?artistId=" + artistData[i].artistId);
# 					aElement.html("&lt;" + artistData[i].nickname + "&gt;의 다른작품");
# 					liElement.append(aElement);
# 					$Element("author_layer_inner").append(liElement);
# 					if (i==9) {
# 						$Element("author_layer").css("border", "1px solid #b6b6b6");
# 						$Element("author_layer_inner").css("border", "0");
# 					}
# 				}
# 				artistLayer.show(element);
# 			}
# 			return false;
# 		},
#
#         artistForBlogUrl : function(element) {
#         	if (currentLevelName == 'WEBTOON' && artistData.length == 1 && $S(artistData[0].blogUrl).trim().$value() != '') {
#         		window.open(artistData[0].blogUrl, '_blank');
#         		return false;
#         	} else {
# 	        	$Element("author_layer_inner").html("");
# 	        	$Element("author_layer").css("border", "");
# 	        	$Element("author_layer_inner").css("border", "1px solid #b6b6b6");
#                 var blogCount = 0;
# 	            if (currentLevelName == 'WEBTOON') {
#
# 	                for (var i = 0; i < artistData.length; i++) {
# 	                    if ($S(artistData[i].blogUrl).trim().$value() != '') {
# 		                    var liElement = new $Element("<li>");
# 		                    var aElement = new $Element("<a>");
# 		                    aElement.attr("href", artistData[i].blogUrl);
# 		                    aElement.attr("target", "_blank");
# 		                    aElement.html("&lt;" + artistData[i].nickname + "&gt;의 블로그")
#
# 		                    liElement.append(aElement);
# 		                    $Element("author_layer_inner").append(liElement);
# 		                    blogCount++;
#
# 		                    if (i==9) {
# 		                        $Element("author_layer").css("border", "1px solid #b6b6b6");
# 		                        $Element("author_layer_inner").css("border", "0");
# 		                    }
# 	                    }
# 	                }
# 	                if (blogCount == 0) {
# 	                    var liElement = new $Element("<li>");
# 	                    var aElement = new $Element("<a>");
# 	                    aElement.html("등록된 블로그가 없습니다.");
#
# 	                    liElement.append(aElement);
# 	                    $Element("author_layer_inner").append(liElement);
# 	                }
# 	            } else {
# 	                for (var i = 0; i < artistData.length; i++) {
# 	                    var liElement = new $Element("<li>");
# 	                    var aElement = new $Element("<a>");
# 	                    aElement.attr("href", artistData[i].blogUrl);
# 	                    aElement.attr("target", "_blank");
# 	                    aElement.html("&lt;" + artistData[i].nickname + "&gt;의 블로그")
#
# 	                    liElement.append(aElement);
# 	                    $Element("author_layer_inner").append(liElement);
#                         blogCount++;
# 	                }
#
#                     if (blogCount == 0) {
#                         var liElement = new $Element("<li>");
#                         var aElement = new $Element("<a>");
#                         aElement.html("등록된 블로그가 없습니다.");
#
#                         liElement.append(aElement);
#                         $Element("author_layer_inner").append(liElement);
#                     }
# 	            }
# 	            artistLayer.show(element);
# 	            return false;
#         	}
#         },
#
#         artistFanCafe : function(element) {
#         	var fancafeUrl = 'https://cafe.naver.com/jamesontheheel/';
#             $Element("author_layer_inner").html("");
#             $Element("author_layer").css("border", "");
#             $Element("author_layer_inner").css("border", "1px solid #b6b6b6");
#
# 			var liElement = new $Element("<li>");
# 			var aElement = new $Element("<a>");
#
# 			if (null != fancafeUrl && '' != fancafeUrl) {
# 				aElement.attr("href", "https://cafe.naver.com/jamesontheheel/");
# 				aElement.attr("target", "_blank");
# 				aElement.html("팬카페 바로가기")
# 			} else {
# 				aElement.attr("href", "javascript:request_fancafe()");
# 				aElement.html("팬카페 등록하기");
# 			}
# 			liElement.append(aElement);
# 			$Element("author_layer_inner").append(liElement);
#             artistLayer.show(element);
#             return false;
#         }
# 	});
#
# 	function request_fancafe() {
#
#
# 		if ( !isLogin)
# 		{
# 			if ( !confirm('로그인 해야 이용할 수 있습니다. 로그인 하겠습니까?'))
# 				return ;
#
# 			document.request_fancafe_form.refresh.value = "true";
# 		}
# 		var form = document.request_fancafe_form;
# 		nwin=open("about:blank", "request_fancafe", "top=10,left=10,toolbar=no,location=0,directories=0,status=yes,menubar=0,scrollbars=no,resizable=0,width=500,height=296");
#
# 		form.target = "request_fancafe";
# 		nwin.blur();
#
#
# 		nwin.focus();
# 		form.submit() ;
#
# 	}
#
# 	function loadThisWindow () {
# 		// 해당 페이지 정보(별점 ajax 호출 시 필요한 정보들)
# 		var oStarInfo = {
# 			"titleId" : 671421
# 			, "no" : 303
# 			, "token" : 'eyJhbGciOiJIUzI1NiJ9.eyJ0aXRsZUlkIjo2NzE0MjEsIm5vIjozMDMsImlkTm8iOiIifQ.7RAyY3jjyETnpTk9GbLAlBHNfKAT2naacMKtK67_pMI'
# 		}
# 	 	new StarScorePoll(isLogin, oStarInfo);
# 	 	new FreeComicShowHideEventRegister(newButtonObject);
#
# 		//$Element("tagBox").css("position","relative");
# 		//$Element("tagBox").css("zIndex","100");
#
# 		if(artistData.length > 1) {
# 	 		$Element("btn_group").addClass("btn_lst");
# 	 		$Element("other_content").className("other2");
# 		}
#
# 		if (false)
# 		{
# 			$Element("comic_before").css("visibility","hidden");
# 		}
# 		if (false)
# 		{
# 			$Element("comic_after").css("visibility","hidden");
# 		}
#
# 		new NavigationBar(navi_init,"/navigationToJson?ln=WEBTOON&titleId=671421&weekday=wed&articleCount=0");
# 	   	new ExtraRemover();
# 		$('commentIframe').src = sCommentUrl;
#
#         // 이미지 실제 위치
#         webtoonContentActualTopMargin = $Element($Element('comic_view_area').query('img')).offset().top ;
#
# 		// 웹툰 PPL
#
#
#         // flex 빅배너 & PPL : 웹툰 PPL이 있을 경우, 베도/도전만화인 경우 미노출되어야 함
#
# 		var oflexVideoAd = new FlexVideoAd();
# 		new FlexAd('671421', '', oflexVideoAd, '');
#
#
# 		// 초기값 체크
# 		eraseCookie("top");
# 		eraseCookie("left");
#
# 		// 리모콘 객체 생성
# 		var remocon = new RemoconComic("comicRemocon");
# 		var drag = new Drag("comicRemocon", remocon, remocon._getRemoconPos[1], remocon._getRemoconPos[1]);
#
# 		// 포텐업 버튼 이벤트
# 		if (jindo.$("potenupAreaBtn")) {
# 			jindo.$Fn(function(oEvent) {
# 				oEvent.stopDefault();
# 				jindo.$Element("potenupAreaBtn").toggleClass('on');
# 			}).attach($("potenupAreaBtn"), "click").attach($("potenupAreaCloseBtn"), "click");
# 		}
# 	}
#
# 	function goUp(){
# 	    var max = $Element('comic_view_area').offset().top;
# 	    window.scrollTo(0,0);
# 	}
#
# 	function goDown(){
#     	var max =  $Element('comic_view_area').first().height();
# 	    window.scrollTo(0,max-($Element("comicRemocon").height()));
#     }
#
# 	function doComicReport() {
# 		var isNaverLogin = false;
#
# 		if (!isNaverLogin) {
# 			if (confirm('로그인 해야 이용할 수 있습니다. 로그인 하시겠습니까?')) {
# 				location.href = 'https://nid.naver.com/nidlogin.login?mode=form&url=' + encodeURIComponent(location.href);
# 			}
# 		} else {
# 			var form = document.reportForm;
# 			var request_report = window.open("about:blank", "request_report", "top=10,left=10,toolbar=no,location=0,directories=0,status=yes,menubar=0,scrollbars=yes,resizable=no,width=580,height=800");
# 			form.target = "request_report";
# 			form.submit();
# 		}
# 	}
#
# 	$Fn(loadThisWindow).attach(window,"load");
#
# 	actionRunner = new WebtoonArtistActionRunner("671421");
#
#
#
# 	/**
# 	 * 시리즈로 이동 가능한지 확인해서 이동
# 	 *
# 	 * @params nbooksId {String} 북스 상품 ID
# 	 */
# 	function moveBookstore(nbooksId) {
# 		var result;
#
#         jQuery.ajax({
#             method: "GET",
#             url: "/api/checkTitleInSeries?nbooksId=" + nbooksId,
#             async: false,
#             success:function(res){
#                 result = res.isExist;
#             }
#         });
#
#
# 		var oInterval = setInterval(function() {
#             if (result) {
#                 window.open('https://series.naver.com/comic/detail.series?originalProductId=' + nbooksId, '_blank');
#             } else {
#                 alert('시리즈에 상품을 등록 중입니다. 잠시만 기다려주세요.');
#             }
#             clearInterval(oInterval);
#             oInterval = null;
# 		}, 200);
# 	}
# </script>
#
# <script type="text/javascript">
# function toogleAlert() {
# 	var alertToolTip = $("alertToolTip");
# 	if(alertToolTip.style.display == "none") {
# 		alertToolTip.style.display = "block";
# 	} else {
# 		alertToolTip.style.display = "none";
# 	}
# }
#
# </script>
# <script type="text/javascript">
#
# 	var g_ssc = "decide.me";
# 	var levelName = "WEBTOON";
# 	if(levelName == "BEST_CHALLENGE"){
#         g_ssc = "comic.best_detail";
# 	}else if(levelName == "CHALLENGE"){
#         g_ssc = "comic.chal_detail";
# 	}else if(levelName == "WEBTOON"){
#         g_ssc = "comic.toon_detail";
# 	}
# 	var ccsrv = "cc.naver.com";
# </script>
#
# <script type="text/javascript">
# function getInitialParams() {
#
# 	return {
#         style  : "standard",
#         text   : "black",
#         evkey  : "cartoon",
#         title  : "언덕 위의 제임스 - 301화 조선 침술사 (1)",
#         url : location.protocol + "//comic.naver.com/webtoon/detail?titleId=671421&no=303",
#         //me2key : "cRHMQWAXT9iVoryGm_eKJQ",
#         tags   : ["웹툰", "만화", "언덕 위의 제임스"],
#         me : {
#             display : "off"
#         },
#         mail : {
#             display : "off"
#         },
#         cafe : {
#             sourceType : "111",
#             sourceTitle : "만화 > 언덕 위의 제임스 > 301화 조선 침술사 (1) | 쿠당탕",
#             sourceForm : "2"
#         },
#         blog : {
#             blogId : "naver",
#             sourceType : "111",
#             sourceTitle : "만화 > 언덕 위의 제임스 > 301화 조선 침술사 (1) | 쿠당탕",
#             sourceForm : "2"
#         },
#         likeServiceId : "COMIC",	// 좋아요 서비스 아이디
#         likeContentsId : "671421_303"	// 좋아요 컨텐츠 아이디
#     };
# }
#
# socialPlugin.init("https://ssl.pstatic.net/spi/js/release");
# </script>
# <script type="text/javascript">
#
#
#
# 	function callWebAdBannerView(sStatsUrl) {
# 		var self = this;
# 		var nTimestamp = new Date().getTime();
#
# 		var oAjax = new $Ajax(sStatsUrl + '&_dummy='+nTimestamp, {
# 			type : "xhr",
# 			method : "get",
# 			timeout : 3,
# 			async : false
# 		}).request();
# 	}
#
# 	function callWebAdBannerClick(sStatsUrl, sTargetUrl) {
# 		var self = this;
# 		var nTimestamp = new Date().getTime();
#
# 		var oAjax = new $Ajax(sStatsUrl + '&_dummy='+nTimestamp, {
# 			type : "xhr",
# 			method : "get",
# 			onload : function(res) {
# 				window.open(sTargetUrl, '_blank');
# 			},
# 			timeout : 3,
# 			async : false
# 		}).request();
# 	}
# </script>
# 			</div>
# 			<!-- side menu -->
#
# 		</div>
#
# 		<!-- Footer -->
#
#
#
#
#
#
#
# <!-- FOOTER Start -->
# <div id="footer">
# 	<div class="naver_corp_info">
# 		<ul>
# 			<li><a href="https://www.naver.com/rules/service.html" onClick="nclk_v2(event,'fot.agreement')" target="_blank">이용약관</a></li>
# 			<li><a href="https://www.naver.com/rules/privacy.html" onclick="nclk_v2(event,'fot.privacy')" target="_blank" class="privacy">개인정보처리방침</a></li>
# 			<li><a href="https://www.naver.com/rules/disclaimer.html" onclick="nclk_v2(event,'fot.disclaimer')" target="_blank">책임의 한계와 법적고지</a></li>
# 			<li><a href="https://help.naver.com/support/home.help?serviceNo=799" onclick="nclk_v2(event,'fot.helpdesk')" target="_blank" title="새 창">고객센터</a></li>
# 			<li><a href="/business/proposalGuide#ad" onClick="nclk_v2(event,'fot.proposal')" target="_blank">웹툰 광고 문의</a></li>
# 		</ul>
# 		<address><a href="https://www.navercorp.com/" target="_blank" onclick="nclk_v2(event,'fot.navercorp')"><span class="naver_corp_link"><span class="blind">ⓒ NAVER CORP.</span></span></a></address>
# 	</div>
#
# 	<div class="webtoon_corp_info">
# 		<ul>
# 			<li><a href="https://member.webtoon.naver.com/policies/terms/" target="_blank">이용약관</a></li>
# 			<li><a href="https://member.webtoon.naver.com/policies/privacy/" target="_blank" class="privacy">개인정보처리방침</a></li>
# 			<li><a href="https://member.webtoon.naver.com/policies/youthpolicy/" target="_blank">청소년보호정책</a></li>
# 			<li><a href="https://help.naver.com/support/service/main.help?serviceNo=799" target="_blank">웹툰 고객센터</a></li>
# 			<li><a href="/business/proposalGuide" target="_blank">웹툰 사업 문의</a></li>
# 		</ul>
# 		<address><a onclick="nclk_v2(event,'fot.wtcorp');" href="https://webtoonscorp.com" class="webtoon_corp_link" target="_blank"><span class="blind">ⓒ NAVER WEBTOON Limited</span></a></address>
# 	</div>
#
# 	<p class="copyright_law">본 콘텐츠의 저작권은 저자 또는 제공처에 있으며, 이를 무단 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.</p>
# </div>
# <!-- //FOOTER End -->
# 	</div>
#
# 		<script type="text/javascript">
# 			var agent = navigator.userAgent.toLowerCase();
#
# 			function loadEvent(){
# 				try{
# 					getGNB();
# 				}catch(ex){
#
# 				}
# 				new naver.comic.RealtimeRankLayer();
# 				if ( $("uploadLinkId") ){
# 					$Fn(function(oEvent) {
# 						oEvent.stop();
# 						if ("true" != "false") {
# 							if (!confirm('로그인해야 이용할 수 있습니다. 로그인 하겠습니까?'))
# 								return false;
# 							else {
# 								location.href = "https://nid.naver.com/nidlogin.login?mode=form&url="
# 										+ encodeURIComponent("https://" + location.host
# 												+ "/upload/upload");
# 								return;
# 							}
# 						}
# 						location.href = "/upload/upload";
# 						return true;
# 					}).attach($("uploadLinkId"),"click");
# 				}
# 				naver.comic.oArtistAction = new naver.comic.Artist();
# 				artistAction = naver.comic.oArtistAction;
# 				naver.comic.oSearchBar = new naver.comic.SearchBarOptionActHandler();
#
# 				// GNB 이벤트 재정의.
# 				$Fn(function(oEvent){
# 					var aWtChild = $Element("gnb" ).child(function (v){return true;});
# 					var wtSrc = $Element(oEvent.element);
# 					var bContain = false;
# 					for (var i = 0 ; i < aWtChild.length ;i++){
# 						if ( aWtChild[i].$value() == wtSrc.$value()){
# 							bContain = true;
# 							break;
# 						}
# 					}
# 					if ( !bContain && gnbAllLayerClose ){
# 						gnbAllLayerClose();
#
# 					}
#
# 				}).attach(document,"click");
# 			}
# 			$Fn(loadEvent).attach(window,'load');
# 		</script>
#
#
#
#
#
#
#
# 				<script type="text/javascript" src="/aggregate/javascript/release/lcslog_20211220192220.js"></script>
#
#
# <script type="text/javascript">
#     try {
#         var eventType = "onpageshow" in window ? "onpageshow" : "onload";
#         var oldEvent = window[eventType];
#         window[eventType] = function() {
#             if (oldEvent) {
#                 oldEvent();
#             }
#             lcs_do();
#         };
#     } catch(ex) { }
# </script>
# 	</body>
#
#
# </html>
