# %%
from tensorflow.keras import models, layers
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(3)
tf.random.set_seed(3)

# %%
dataset = np.loadtxt("E:\source\TF\dataset\pima-indians-diabetes.csv", delimiter=',')
X =dataset[:, 0:8]
y =dataset[:, 8]

# %%
model_name = 'pima-indians-diabetes'
BATH_SIZE = 10
params = {'model_name' : model_name,
         'input_dimension' : 8,
         'hidden1_dimension' : 12, 
         'hidden2_dimension' : 8,
         'output_dimension' : 1}

# %%
class PimaIndiansDiabetes(tf.keras.Model): #반드시 케라스의 모델을 상속받아야함
    def __init__(self, **kargs):  #딕셔너리타입의 파라미터를 받아야함
        super(PimaIndiansDiabetes, self).__init__(name=kargs['model_name']) #틀이 고정임
        self.fc1 = layers.Dense(kargs['hidden1_dimension'], input_dim=kargs['input_dimension'], 
                               activation='relu')
        self.fc2 = layers.Dense(kargs['hidden2_dimension'], activation='relu')
        self.fc3 = layers.Dense(kargs['output_dimension'], activation='sigmoid')
        
    def call(self, x):
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        return x

# %%
model = PimaIndiansDiabetes(**params)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']) #만들 때 매트릭스 설정 accuray를 출력
model.fit(X, y, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 77/77 [==============================] - 0s 824us/step - loss: 10.5440 - accuracy: 0.6159
# Epoch 2/100
# 77/77 [==============================] - 0s 688us/step - loss: 5.4367 - accuracy: 0.6029
# Epoch 3/100
# 77/77 [==============================] - 0s 696us/step - loss: 2.9292 - accuracy: 0.5208
# Epoch 4/100
# 77/77 [==============================] - 0s 732us/step - loss: 1.5346 - accuracy: 0.5208
# Epoch 5/100
# 77/77 [==============================] - 0s 696us/step - loss: 0.8896 - accuracy: 0.5000
# Epoch 6/100
# 77/77 [==============================] - 0s 709us/step - loss: 0.8072 - accuracy: 0.5234
# Epoch 7/100
# 77/77 [==============================] - 0s 787us/step - loss: 0.7655 - accuracy: 0.6549
# Epoch 8/100
# 77/77 [==============================] - 0s 684us/step - loss: 0.7306 - accuracy: 0.6628
# Epoch 9/100
# 77/77 [==============================] - 0s 992us/step - loss: 0.6943 - accuracy: 0.6706
# Epoch 10/100
# ...
